# %% [markdown]
# # Maple et al., 2025 Plot for Figure S2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# import matplotlib
from matplotlib import rc
import seaborn as sns
from matplotlib.ticker import MultipleLocator

# plt.rcdefaults()
rc('font',**{'family':'sans-serif','sans-serif':['Arial']})

# %% [markdown]
# ## Make a boxplot of the ActD untreated smFISH data, comparing NV and 1W cold treatment

# %%
# Make lists of NV and cold FLC data (Number of foci per unit area; n=38 cells for NV; n=56 cells for 1W cold)
nv_flc_data = [
    0.48470781,
    0.522916026,
    0.633397313,
    0.659596482,
    0.463814474,
    0.231131656,
    0.495356037,
    0.439257028,
    0.64333018,
    0.69234866,
    0.565352697,
    0.653310105,
    0.598517309,
    0.60142396,
    0.467152056,
    0.337011469,
    0.701005791,
    0.762925087,
    0.672517018,
    0.587536721,
    0.492918201,
    0.54950216,
    0.462189006,
    0.456578887,
    0.323358544,
    0.329008341,
    0.371326075,
    0.470559352,
    0.34355516,
    0.486562685,
    0.197921821,
    0.351082504,
    0.489183607,
    0.410805837,
    0.519037697,
    0.591798049,
    0.393007183,
    0.439528453
]

cold_flc_data = [
    0.2687187,
    0.297054734,
    0.176174497,
    0.185377428,
    0.204296824,
    0.155908949,
    0.189625642,
    0.146474158,
    0.248926504,
    0.378020791,
    0.283036669,
    0.326264274,
    0.301372036,
    0.311041991,
    0.340888703,
    0.208865166,
    0.193006358,
    0.245188182,
    0.237880404,
    0.121536218,
    0.198154334,
    0.147983722,
    0.299257841,
    0.415973378,
    0.314465409,
    0.422052229,
    0.333765993,
    0.335795836,
    0.380904012,
    0.341024525,
    0.402106271,
    0.377620988,
    0.357451005,
    0.4026228,
    0.438058525,
    0.283194433,
    0.2485259,
    0.294233033,
    0.2364765,
    0.311403012,
    0.427153082,
    0.312695435,
    0.364744951,
    0.441426146,
    0.383500557,
    0.342465753,
    0.299919253,
    0.23995201,
    0.250898488,
    0.407069102,
    0.358337315,
    0.310634669,
    0.350478356,
    0.415002741,
    0.440067058,
    0.41024706
]

#Make a box plot of the above data

# Create a box plot with individual data points
plt.figure(figsize=(4, 6))
sns.boxplot(data=[nv_flc_data, cold_flc_data], palette="Set2",showmeans = True, meanline=True)
sns.stripplot(data=[nv_flc_data, cold_flc_data], color='black', jitter=0.2, size=5, alpha=0.6)
plt.xticks([0, 1], ['NV', 'Cold (1W)'])
plt.ylabel('mRNA foci per unit area')
plt.title('FLC smFISH ActD untreated')

plt.savefig('FLC_smFISH_boxplots.pdf',bbox_inches='tight')
plt.show()
plt.show()
