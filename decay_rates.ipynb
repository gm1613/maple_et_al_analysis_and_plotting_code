# %% [markdown]
# # Maple et al., 2025 Figure 2B,D plots and calculating *FLC* mRNA decay rates from smFISH data

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# import matplotlib
from matplotlib import rc
import seaborn as sns
from matplotlib.ticker import MultipleLocator

# plt.rcdefaults()
rc('font',**{'family':'sans-serif','sans-serif':['Arial']})

# %% [markdown]
# ## Calculate *FLC* and *PP2A* mRNA decay rates at NV (non-vernalised) timepoint

# %%
# Mean values (foci per micron squared per cell): See Excel file for calculation
flc_mean_6h = 0.225878
pp2a_mean_6h = 0.02382859

flc_mean_4h = 0.385443568
pp2a_mean_4h = 0.059848866

# Standard error of the mean (n=71 for 4h and n=46 for 6h): See Excel file for calculation
flc_sem_6h = 0.01373583
pp2a_sem_6h = 0.002952477

flc_sem_4h = 0.013465227
pp2a_sem_4h = 0.009000419

# Calculate the FLC decay constant

k_mean_flc = 0.5*np.log(flc_mean_4h/flc_mean_6h)
k_sem_flc = 0.5*np.sqrt((flc_sem_4h/flc_mean_4h)**2 + (flc_sem_6h/flc_mean_6h)**2)

print("k_flc = {:.3f} +/- {:.3f}".format(k_mean_flc, k_sem_flc))

# Calculate the FLC half-life

t_half_mean_flc = np.log(2)/k_mean_flc
t_half_sem_flc = t_half_mean_flc*k_sem_flc/k_mean_flc

print("t_half_flc = {:.3f} +/- {:.3f}".format(t_half_mean_flc, t_half_sem_flc))

# Calculate the PP2A decay constant

k_mean_pp2a = 0.5*np.log(pp2a_mean_4h/pp2a_mean_6h)
k_sem_pp2a = 0.5*np.sqrt((pp2a_sem_4h/pp2a_mean_4h)**2 + (pp2a_sem_6h/pp2a_mean_6h)**2)

print("k_pp2a = {:.3f} +/- {:.3f}".format(k_mean_pp2a, k_sem_pp2a))

# Calculate the PP2A half-life

t_half_mean_pp2a = np.log(2)/k_mean_pp2a
t_half_sem_pp2a = t_half_mean_pp2a*k_sem_pp2a/k_mean_pp2a

print("t_half_pp2a = {:.3f} +/- {:.3f}".format(t_half_mean_pp2a, t_half_sem_pp2a))
# Out:
# k_flc = 0.267 +/- 0.035
# t_half_flc = 2.594 +/- 0.340
# k_pp2a = 0.460 +/- 0.097
# t_half_pp2a = 1.505 +/- 0.318

# %% [markdown]
# ## Calculate *FLC* and *PP2A* mRNA decay rates at 1W cold timepoint

# %%
# Mean values (foci per micron squared per cell): See Excel file for calculation
flc_mean_6h = 0.113128961
pp2a_mean_6h = 0.008075453

flc_mean_4h = 0.182004088
pp2a_mean_4h = 0.032006567

# Standard error of the mean (n=71 for 4h and n=46 for 6h): See Excel file for calculation
flc_sem_6h = 0.012323691
pp2a_sem_6h = 0.002010134

flc_sem_4h = 0.009731501
pp2a_sem_4h = 0.003584625

# Calculate the FLC decay constant

k_mean_flc = 0.5*np.log(flc_mean_4h/flc_mean_6h)
k_sem_flc = 0.5*np.sqrt((flc_sem_4h/flc_mean_4h)**2 + (flc_sem_6h/flc_mean_6h)**2)

print("k_flc = {:.3f} +/- {:.3f}".format(k_mean_flc, k_sem_flc))

# Calculate the FLC half-life

t_half_mean_flc = np.log(2)/k_mean_flc
t_half_sem_flc = t_half_mean_flc*k_sem_flc/k_mean_flc

print("t_half_flc = {:.3f} +/- {:.3f}".format(t_half_mean_flc, t_half_sem_flc))

# Calculate the PP2A decay constant

k_mean_pp2a = 0.5*np.log(pp2a_mean_4h/pp2a_mean_6h)
k_sem_pp2a = 0.5*np.sqrt((pp2a_sem_4h/pp2a_mean_4h)**2 + (pp2a_sem_6h/pp2a_mean_6h)**2)

print("k_pp2a = {:.3f} +/- {:.3f}".format(k_mean_pp2a, k_sem_pp2a))

# Calculate the PP2A half-life

t_half_mean_pp2a = np.log(2)/k_mean_pp2a
t_half_sem_pp2a = t_half_mean_pp2a*k_sem_pp2a/k_mean_pp2a

print("t_half_pp2a = {:.3f} +/- {:.3f}".format(t_half_mean_pp2a, t_half_sem_pp2a))

j = np.log(2)
# Out:
# k_flc = 0.238 +/- 0.061
# t_half_flc = 2.915 +/- 0.744
# k_pp2a = 0.689 +/- 0.136
# t_half_pp2a = 1.007 +/- 0.200

# %% [markdown]
# ## Plot mRNA decay data for *FLC*: Figure 2B

# %% [markdown]
# ### Input data for *FLC* mRNA

# %%
nv_flc_0 = [
    0.975033277,
    1.051892534,
    1.274135562,
    1.326837543,
    0.933004457,
    0.464942078,
    0.996453142,
    0.883604949,
    1.294116415,
    1.392721489,
    1.137257708,
    1.31419193,
    1.203971303,
    1.209818291,
    0.939718302,
    0.677928828,
    1.410136085,
    1.534692309,
    1.352828361,
    1.181882864,
    0.991549215,
    1.105372931,
    0.929734681,
    0.918449423,
    0.650464743,
    0.661829817,
    0.746955737,
    0.946572384,
    0.691092048,
    0.978764524,
    0.398137512,
    0.706233978,
    0.984036745,
    0.826372823,
    1.044090926,
    1.190454908,
    0.790569232,
    0.884150944
]

nv_flc_4 = [
    0.922427052,
    0.858699642,
    0.554029777,
    0.585402628,
    0.898351992,
    0.721210941,
    0.661272117,
    1.054328376,
    0.496688835,
    0.426601422,
    0.757565823,
    0.522067096,
    0.77915614,
    1.135827563,
    0.895100763,
    0.996077065,
    0.830831542,
    0.918227355,
    0.542739455,
    0.523600327,
    0.935198787,
    0.898914014,
    0.799155986,
    0.425610456,
    0.845860481,
    0.934081534,
    0.97986123,
    0.899522708,
    0.529764051,
    0.4243589,
    0.569007084,
    1.001515687,
    0.637555293,
    1.069132916,
    0.836171524,
    0.889841675,
    0.996215892,
    0.7114909,
    0.76939276,
    0.562558225,
    0.603476934,
    0.370146092,
    0.583609381,
    0.496076395,
    0.433688059,
    0.333719964,
    0.305891533,
    0.192819533,
    0.383452112,
    0.227212701,
    0.305284464,
    0.544224493,
    0.703199399,
    0.596173805,
    0.32970876,
    0.460866427,
    0.736746122,
    0.651514188,
    0.662560002,
    0.777825748,
    0.809153687,
    0.749893674,
    0.995118103,
    0.572939271,
    0.567425614,
    0.524727453,
    0.849796528,
    0.910553891,
    0.719631301,
    0.308413415,
    0.543395064
]

nv_flc_6 = [
    0.169879851,
    0.212230327,
    0.236430042,
    0.034510032,
    0.360228142,
    0.117341728,
    0.219787206,
    0,
    0,
    0.165514419,
    0.439782052,
    0.083267919,
    0.049421058
]

w1_pp2a_0 = [
    2.029600496,
    2.567167121,
    0.929325462,
    1.095215731,
    1.095053332,
    1.295317997,
    1.694023658,
    1.255564916,
    0.919166055,
    2.243329183,
    1.045118514,
    0.547607865,
    1.464239764,
    1.747761096,
    2.097897162,
    0.856931965,
    2.30572878,
    2.489746119,
    1.96877852,
    0.598366527,
    0.836215781,
    0.45536069,
    0.88401241,
    1.228791959,
    0.74433959,
    1.217528302,
    1.027031291,
    0.495973114,
    1.40649562,
    1.071693466,
    0.176760164,
    0.73388052,
    0.796488317,
    0.424769336,
    1.294031833,
    0.448157598,
    0.089969296,
    0.482871693,
    0.181915452,
    0.940796017,
    0.213144761,
    1.000682882,
    0.804076397,
    0.313456692,
    0.329321724,
    0.824714079,
    1.703781214,
    0.369178148,
    0.751173765,
    1.283143311,
    0.588074508,
    0.562266999,
    0.699539611,
    0.28913318,
    0.58034155,
    0.504948469
]

w1_pp2a_4 = [
    0.671557178,
    0.818575538,
    1.307395197,
    0.495995321,
    0.445848809,
    0.470065327,
    0.295732808,
    0.090671836,
    0.584259468,
    0.755487322,
    0.384104005,
    0.412618151,
    0.336050222,
    0.519309287,
    0.962166425,
    0.828033497,
    0.684002637,
    1.336215374,
    0.633365323,
    0.523588387,
    1.186901324,
    0.1733903,
    0.762523456,
    0.867960236,
    1.032397587,
    0.571391113,
    1.686467155,
    1.109326074,
    0.275602316,
    0.516465234,
    0.376593677,
    0,
    0,
    0,
    0,
    0.334225184,
    0.415917981
]

w1_pp2a_6 = [
    0.21027219,
    0.134980254,
    0.150139052,
    0.19405717,
    0.332061136,
    0.204866835,
    0,
    0,
    0,
    0,
    0,
    0.695127981,
    0,
    0.115676822,
    0.283647245,
    0.123910062,
    0.183634366,
    0.163559525,
    0.189944436,
    0
]

# %% [markdown]
# ### Make the plot

# %%
# Make a plot of the pp2a data
nv_data = [nv_pp2a_0, nv_pp2a_4, nv_pp2a_6]
w1_data = [w1_pp2a_0, w1_pp2a_4, w1_pp2a_6]
plt.figure(figsize=(6, 6))
sns.stripplot(data=nv_data, color='red', jitter=0.2, size=5, alpha=0.6)
sns.pointplot(data=nv_data, color='red', errorbar='sd', capsize=0.1, markers='D',linestyle='none')
sns.stripplot(data=w1_data, color='blue', jitter=0.2, size=5, alpha=0.6)
sns.pointplot(data=w1_data, color='blue', errorbar='sd', capsize=0.1, markers='D',linestyle='none')
#Set xtick labels
plt.xticks([0,1,2], ['0','4', '6'])
plt.ylabel('Relative mRNA per unit area', fontsize=16)
plt.xlabel('Time (h)', fontsize=16)
plt.title('PP2A mRNA decay', fontsize=16)
#Set xtick label size
plt.xticks(fontsize=16)
#Set ytick label size
plt.yticks(fontsize=16)
#Set yticks
plt.yticks(np.arange(0, 3.1, 0.5))

plt.savefig('pp2a_smFISH_decayplot_v2.pdf',bbox_inches='tight')
plt.show()
